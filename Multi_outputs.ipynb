# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)
# .reset_index() : Reset the index of the DataFrame, and use the default one instead.
# If the DataFrame has a MultiIndex, this method can remove one or more levels.
# Return DataFrame with the new index or None if inplace=True.


# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 5ms/step - loss: 611.2217 - y1_output_loss: 290.9766 - y2_output_loss: 320.2451 - y1_output_root_mean_squared_error: 16.3926 - y2_output_root_mean_squared_error: 17.1494 - val_loss: 61.4005 - val_y1_output_loss: 18.6438 - val_y2_output_loss: 42.7567 - val_y1_output_root_mean_squared_error: 4.3178 - val_y2_output_root_mean_squared_error: 6.5389
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 32.1759 - y1_output_loss: 12.4964 - y2_output_loss: 19.6796 - y1_output_root_mean_squared_error: 3.5285 - y2_output_root_mean_squared_error: 4.4233 - val_loss: 25.2819 - val_y1_output_loss: 10.0704 - val_y2_output_loss: 15.2115 - val_y1_output_root_mean_squared_error: 3.1734 - val_y2_output_root_mean_squared_error: 3.9002
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.4516 - y1_output_loss: 9.4495 - y2_output_loss: 13.0021 - y1_output_root_mean_squared_error: 3.0587 - y2_output_root_mean_squared_error: 3.5990 - val_loss: 36.6920 - val_y1_output_loss: 13.3583 - val_y2_output_loss: 23.3337 - val_y1_output_root_mean_squared_error: 3.6549 - val_y2_output_root_mean_squared_error: 4.8305
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 24.4167 - y1_output_loss: 10.4214 - y2_output_loss: 13.9953 - y1_output_root_mean_squared_error: 3.2176 - y2_output_root_mean_squared_error: 3.7316 - val_loss: 38.6417 - val_y1_output_loss: 10.7638 - val_y2_output_loss: 27.8778 - val_y1_output_root_mean_squared_error: 3.2808 - val_y2_output_root_mean_squared_error: 5.2799
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.7342 - y1_output_loss: 8.8239 - y2_output_loss: 13.9102 - y1_output_root_mean_squared_error: 2.9652 - y2_output_root_mean_squared_error: 3.7126 - val_loss: 22.9165 - val_y1_output_loss: 9.3390 - val_y2_output_loss: 13.5775 - val_y1_output_root_mean_squared_error: 3.0560 - val_y2_output_root_mean_squared_error: 3.6848
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 23.3289 - y1_output_loss: 9.2080 - y2_output_loss: 14.1209 - y1_output_root_mean_squared_error: 3.0265 - y2_output_root_mean_squared_error: 3.7475 - val_loss: 23.0823 - val_y1_output_loss: 8.9175 - val_y2_output_loss: 14.1648 - val_y1_output_root_mean_squared_error: 2.9862 - val_y2_output_root_mean_squared_error: 3.7636
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.9089 - y1_output_loss: 7.8108 - y2_output_loss: 12.0981 - y1_output_root_mean_squared_error: 2.7906 - y2_output_root_mean_squared_error: 3.4680 - val_loss: 76.0554 - val_y1_output_loss: 21.6999 - val_y2_output_loss: 54.3554 - val_y1_output_root_mean_squared_error: 4.6583 - val_y2_output_root_mean_squared_error: 7.3726
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 23.2248 - y1_output_loss: 9.6100 - y2_output_loss: 13.6148 - y1_output_root_mean_squared_error: 3.0833 - y2_output_root_mean_squared_error: 3.6477 - val_loss: 36.8961 - val_y1_output_loss: 11.1291 - val_y2_output_loss: 25.7670 - val_y1_output_root_mean_squared_error: 3.3360 - val_y2_output_root_mean_squared_error: 5.0761
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.9588 - y1_output_loss: 7.8630 - y2_output_loss: 13.0959 - y1_output_root_mean_squared_error: 2.7925 - y2_output_root_mean_squared_error: 3.6140 - val_loss: 24.2135 - val_y1_output_loss: 9.5349 - val_y2_output_loss: 14.6786 - val_y1_output_root_mean_squared_error: 3.0879 - val_y2_output_root_mean_squared_error: 3.8313
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.8406 - y1_output_loss: 8.0669 - y2_output_loss: 13.7738 - y1_output_root_mean_squared_error: 2.8384 - y2_output_root_mean_squared_error: 3.7046 - val_loss: 25.7570 - val_y1_output_loss: 9.6642 - val_y2_output_loss: 16.0928 - val_y1_output_root_mean_squared_error: 3.1087 - val_y2_output_root_mean_squared_error: 4.0116
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 28.4333 - y1_output_loss: 10.0601 - y2_output_loss: 18.3732 - y1_output_root_mean_squared_error: 3.1644 - y2_output_root_mean_squared_error: 4.2529 - val_loss: 27.1400 - val_y1_output_loss: 9.7062 - val_y2_output_loss: 17.4338 - val_y1_output_root_mean_squared_error: 3.1155 - val_y2_output_root_mean_squared_error: 4.1754
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.7435 - y1_output_loss: 7.9752 - y2_output_loss: 11.7683 - y1_output_root_mean_squared_error: 2.8191 - y2_output_root_mean_squared_error: 3.4237 - val_loss: 21.3257 - val_y1_output_loss: 8.8363 - val_y2_output_loss: 12.4895 - val_y1_output_root_mean_squared_error: 2.9726 - val_y2_output_root_mean_squared_error: 3.5340
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.9080 - y1_output_loss: 7.2196 - y2_output_loss: 10.6883 - y1_output_root_mean_squared_error: 2.6836 - y2_output_root_mean_squared_error: 3.2648 - val_loss: 54.0231 - val_y1_output_loss: 13.3376 - val_y2_output_loss: 40.6855 - val_y1_output_root_mean_squared_error: 3.6521 - val_y2_output_root_mean_squared_error: 6.3785
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.5003 - y1_output_loss: 7.6519 - y2_output_loss: 12.8484 - y1_output_root_mean_squared_error: 2.7641 - y2_output_root_mean_squared_error: 3.5507 - val_loss: 25.2792 - val_y1_output_loss: 10.9008 - val_y2_output_loss: 14.3784 - val_y1_output_root_mean_squared_error: 3.3016 - val_y2_output_root_mean_squared_error: 3.7919
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.8910 - y1_output_loss: 8.0802 - y2_output_loss: 11.8107 - y1_output_root_mean_squared_error: 2.8401 - y2_output_root_mean_squared_error: 3.4340 - val_loss: 25.2765 - val_y1_output_loss: 10.3761 - val_y2_output_loss: 14.9005 - val_y1_output_root_mean_squared_error: 3.2212 - val_y2_output_root_mean_squared_error: 3.8601
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.0123 - y1_output_loss: 7.6897 - y2_output_loss: 11.3226 - y1_output_root_mean_squared_error: 2.7692 - y2_output_root_mean_squared_error: 3.3577 - val_loss: 22.5169 - val_y1_output_loss: 8.8041 - val_y2_output_loss: 13.7129 - val_y1_output_root_mean_squared_error: 2.9672 - val_y2_output_root_mean_squared_error: 3.7031
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.4268 - y1_output_loss: 6.9506 - y2_output_loss: 11.4762 - y1_output_root_mean_squared_error: 2.6332 - y2_output_root_mean_squared_error: 3.3755 - val_loss: 31.7446 - val_y1_output_loss: 11.4212 - val_y2_output_loss: 20.3234 - val_y1_output_root_mean_squared_error: 3.3795 - val_y2_output_root_mean_squared_error: 4.5081
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.0360 - y1_output_loss: 7.4232 - y2_output_loss: 11.6128 - y1_output_root_mean_squared_error: 2.7198 - y2_output_root_mean_squared_error: 3.4054 - val_loss: 35.7337 - val_y1_output_loss: 11.3474 - val_y2_output_loss: 24.3863 - val_y1_output_root_mean_squared_error: 3.3686 - val_y2_output_root_mean_squared_error: 4.9383
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.8977 - y1_output_loss: 6.6117 - y2_output_loss: 10.2860 - y1_output_root_mean_squared_error: 2.5646 - y2_output_root_mean_squared_error: 3.1950 - val_loss: 38.1339 - val_y1_output_loss: 11.2443 - val_y2_output_loss: 26.8896 - val_y1_output_root_mean_squared_error: 3.3533 - val_y2_output_root_mean_squared_error: 5.1855
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.2756 - y1_output_loss: 7.1715 - y2_output_loss: 11.1041 - y1_output_root_mean_squared_error: 2.6730 - y2_output_root_mean_squared_error: 3.3209 - val_loss: 24.5175 - val_y1_output_loss: 9.5306 - val_y2_output_loss: 14.9870 - val_y1_output_root_mean_squared_error: 3.0872 - val_y2_output_root_mean_squared_error: 3.8713
# Epoch 21/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.6172 - y1_output_loss: 6.1959 - y2_output_loss: 10.4213 - y1_output_root_mean_squared_error: 2.4739 - y2_output_root_mean_squared_error: 3.2163 - val_loss: 23.5759 - val_y1_output_loss: 8.2547 - val_y2_output_loss: 15.3212 - val_y1_output_root_mean_squared_error: 2.8731 - val_y2_output_root_mean_squared_error: 3.9142
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 24.1886 - y1_output_loss: 8.1410 - y2_output_loss: 16.0477 - y1_output_root_mean_squared_error: 2.8404 - y2_output_root_mean_squared_error: 3.9761 - val_loss: 21.2762 - val_y1_output_loss: 7.8586 - val_y2_output_loss: 13.4177 - val_y1_output_root_mean_squared_error: 2.8033 - val_y2_output_root_mean_squared_error: 3.6630
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.8426 - y1_output_loss: 5.9060 - y2_output_loss: 8.9366 - y1_output_root_mean_squared_error: 2.4234 - y2_output_root_mean_squared_error: 2.9533 - val_loss: 17.6303 - val_y1_output_loss: 7.0805 - val_y2_output_loss: 10.5498 - val_y1_output_root_mean_squared_error: 2.6609 - val_y2_output_root_mean_squared_error: 3.2480
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.2585 - y1_output_loss: 5.5678 - y2_output_loss: 8.6906 - y1_output_root_mean_squared_error: 2.3570 - y2_output_root_mean_squared_error: 2.9419 - val_loss: 16.8468 - val_y1_output_loss: 6.5766 - val_y2_output_loss: 10.2702 - val_y1_output_root_mean_squared_error: 2.5645 - val_y2_output_root_mean_squared_error: 3.2047
# Epoch 25/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.8507 - y1_output_loss: 6.2744 - y2_output_loss: 8.5764 - y1_output_root_mean_squared_error: 2.4991 - y2_output_root_mean_squared_error: 2.9240 - val_loss: 36.5001 - val_y1_output_loss: 9.0610 - val_y2_output_loss: 27.4391 - val_y1_output_root_mean_squared_error: 3.0101 - val_y2_output_root_mean_squared_error: 5.2382
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.9093 - y1_output_loss: 5.4211 - y2_output_loss: 11.4882 - y1_output_root_mean_squared_error: 2.3234 - y2_output_root_mean_squared_error: 3.3768 - val_loss: 38.5057 - val_y1_output_loss: 12.5577 - val_y2_output_loss: 25.9480 - val_y1_output_root_mean_squared_error: 3.5437 - val_y2_output_root_mean_squared_error: 5.0939
# Epoch 27/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.2931 - y1_output_loss: 5.5435 - y2_output_loss: 9.7496 - y1_output_root_mean_squared_error: 2.3486 - y2_output_root_mean_squared_error: 3.1145 - val_loss: 24.9223 - val_y1_output_loss: 9.8222 - val_y2_output_loss: 15.1001 - val_y1_output_root_mean_squared_error: 3.1340 - val_y2_output_root_mean_squared_error: 3.8859
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.0628 - y1_output_loss: 4.7842 - y2_output_loss: 7.2786 - y1_output_root_mean_squared_error: 2.1771 - y2_output_root_mean_squared_error: 2.6722 - val_loss: 15.2559 - val_y1_output_loss: 6.3846 - val_y2_output_loss: 8.8713 - val_y1_output_root_mean_squared_error: 2.5268 - val_y2_output_root_mean_squared_error: 2.9785
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.8386 - y1_output_loss: 5.1035 - y2_output_loss: 8.7351 - y1_output_root_mean_squared_error: 2.2558 - y2_output_root_mean_squared_error: 2.9353 - val_loss: 31.5315 - val_y1_output_loss: 8.6878 - val_y2_output_loss: 22.8437 - val_y1_output_root_mean_squared_error: 2.9475 - val_y2_output_root_mean_squared_error: 4.7795
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.1689 - y1_output_loss: 4.5261 - y2_output_loss: 8.6428 - y1_output_root_mean_squared_error: 2.1147 - y2_output_root_mean_squared_error: 2.9354 - val_loss: 15.5259 - val_y1_output_loss: 6.3358 - val_y2_output_loss: 9.1901 - val_y1_output_root_mean_squared_error: 2.5171 - val_y2_output_root_mean_squared_error: 3.0315
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.9286 - y1_output_loss: 6.2479 - y2_output_loss: 11.6807 - y1_output_root_mean_squared_error: 2.4869 - y2_output_root_mean_squared_error: 3.3841 - val_loss: 14.1780 - val_y1_output_loss: 5.9445 - val_y2_output_loss: 8.2335 - val_y1_output_root_mean_squared_error: 2.4381 - val_y2_output_root_mean_squared_error: 2.8694
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.9020 - y1_output_loss: 4.9352 - y2_output_loss: 7.9667 - y1_output_root_mean_squared_error: 2.2194 - y2_output_root_mean_squared_error: 2.8052 - val_loss: 16.9198 - val_y1_output_loss: 6.6163 - val_y2_output_loss: 10.3035 - val_y1_output_root_mean_squared_error: 2.5722 - val_y2_output_root_mean_squared_error: 3.2099
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.6916 - y1_output_loss: 4.2538 - y2_output_loss: 5.4378 - y1_output_root_mean_squared_error: 2.0605 - y2_output_root_mean_squared_error: 2.3277 - val_loss: 21.2357 - val_y1_output_loss: 7.0450 - val_y2_output_loss: 14.1907 - val_y1_output_root_mean_squared_error: 2.6542 - val_y2_output_root_mean_squared_error: 3.7671
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.8360 - y1_output_loss: 4.2031 - y2_output_loss: 8.6330 - y1_output_root_mean_squared_error: 2.0429 - y2_output_root_mean_squared_error: 2.9328 - val_loss: 12.8927 - val_y1_output_loss: 5.2538 - val_y2_output_loss: 7.6389 - val_y1_output_root_mean_squared_error: 2.2921 - val_y2_output_root_mean_squared_error: 2.7639
# Epoch 35/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.9466 - y1_output_loss: 3.6422 - y2_output_loss: 6.3044 - y1_output_root_mean_squared_error: 1.9045 - y2_output_root_mean_squared_error: 2.5056 - val_loss: 23.1979 - val_y1_output_loss: 7.1784 - val_y2_output_loss: 16.0195 - val_y1_output_root_mean_squared_error: 2.6793 - val_y2_output_root_mean_squared_error: 4.0024
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.5229 - y1_output_loss: 4.1705 - y2_output_loss: 8.3524 - y1_output_root_mean_squared_error: 2.0340 - y2_output_root_mean_squared_error: 2.8813 - val_loss: 11.8770 - val_y1_output_loss: 4.6209 - val_y2_output_loss: 7.2560 - val_y1_output_root_mean_squared_error: 2.1496 - val_y2_output_root_mean_squared_error: 2.6937
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.4756 - y1_output_loss: 3.9905 - y2_output_loss: 6.4851 - y1_output_root_mean_squared_error: 1.9954 - y2_output_root_mean_squared_error: 2.5403 - val_loss: 13.7313 - val_y1_output_loss: 6.4213 - val_y2_output_loss: 7.3100 - val_y1_output_root_mean_squared_error: 2.5340 - val_y2_output_root_mean_squared_error: 2.7037
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.8739 - y1_output_loss: 3.4824 - y2_output_loss: 6.3915 - y1_output_root_mean_squared_error: 1.8570 - y2_output_root_mean_squared_error: 2.5249 - val_loss: 12.7906 - val_y1_output_loss: 4.7860 - val_y2_output_loss: 8.0046 - val_y1_output_root_mean_squared_error: 2.1877 - val_y2_output_root_mean_squared_error: 2.8292
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.6520 - y1_output_loss: 4.3231 - y2_output_loss: 7.3289 - y1_output_root_mean_squared_error: 2.0682 - y2_output_root_mean_squared_error: 2.6911 - val_loss: 11.6224 - val_y1_output_loss: 4.1373 - val_y2_output_loss: 7.4851 - val_y1_output_root_mean_squared_error: 2.0340 - val_y2_output_root_mean_squared_error: 2.7359
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.7589 - y1_output_loss: 3.8183 - y2_output_loss: 5.9406 - y1_output_root_mean_squared_error: 1.9518 - y2_output_root_mean_squared_error: 2.4202 - val_loss: 19.8119 - val_y1_output_loss: 7.0332 - val_y2_output_loss: 12.7786 - val_y1_output_root_mean_squared_error: 2.6520 - val_y2_output_root_mean_squared_error: 3.5747
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2986 - y1_output_loss: 2.9717 - y2_output_loss: 5.3269 - y1_output_root_mean_squared_error: 1.7215 - y2_output_root_mean_squared_error: 2.3020 - val_loss: 10.6616 - val_y1_output_loss: 3.9967 - val_y2_output_loss: 6.6649 - val_y1_output_root_mean_squared_error: 1.9992 - val_y2_output_root_mean_squared_error: 2.5816
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2584 - y1_output_loss: 3.2719 - y2_output_loss: 4.9865 - y1_output_root_mean_squared_error: 1.8072 - y2_output_root_mean_squared_error: 2.2263 - val_loss: 31.5981 - val_y1_output_loss: 7.6735 - val_y2_output_loss: 23.9246 - val_y1_output_root_mean_squared_error: 2.7701 - val_y2_output_root_mean_squared_error: 4.8913
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.5609 - y1_output_loss: 3.6816 - y2_output_loss: 6.8793 - y1_output_root_mean_squared_error: 1.9115 - y2_output_root_mean_squared_error: 2.6054 - val_loss: 12.6929 - val_y1_output_loss: 4.0479 - val_y2_output_loss: 8.6451 - val_y1_output_root_mean_squared_error: 2.0119 - val_y2_output_root_mean_squared_error: 2.9402
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.9716 - y1_output_loss: 3.5414 - y2_output_loss: 5.4302 - y1_output_root_mean_squared_error: 1.8748 - y2_output_root_mean_squared_error: 2.3235 - val_loss: 10.1043 - val_y1_output_loss: 3.8882 - val_y2_output_loss: 6.2160 - val_y1_output_root_mean_squared_error: 1.9719 - val_y2_output_root_mean_squared_error: 2.4932
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1775 - y1_output_loss: 2.6247 - y2_output_loss: 4.5528 - y1_output_root_mean_squared_error: 1.6133 - y2_output_root_mean_squared_error: 2.1254 - val_loss: 9.8538 - val_y1_output_loss: 4.0398 - val_y2_output_loss: 5.8140 - val_y1_output_root_mean_squared_error: 2.0099 - val_y2_output_root_mean_squared_error: 2.4112
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.9958 - y1_output_loss: 2.8373 - y2_output_loss: 5.1585 - y1_output_root_mean_squared_error: 1.6785 - y2_output_root_mean_squared_error: 2.2663 - val_loss: 25.9111 - val_y1_output_loss: 6.2888 - val_y2_output_loss: 19.6223 - val_y1_output_root_mean_squared_error: 2.5078 - val_y2_output_root_mean_squared_error: 4.4297
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.6035 - y1_output_loss: 4.0338 - y2_output_loss: 8.5697 - y1_output_root_mean_squared_error: 2.0007 - y2_output_root_mean_squared_error: 2.8902 - val_loss: 21.0238 - val_y1_output_loss: 6.1374 - val_y2_output_loss: 14.8863 - val_y1_output_root_mean_squared_error: 2.4774 - val_y2_output_root_mean_squared_error: 3.8583
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.3205 - y1_output_loss: 3.3978 - y2_output_loss: 6.9227 - y1_output_root_mean_squared_error: 1.8340 - y2_output_root_mean_squared_error: 2.5835 - val_loss: 9.1822 - val_y1_output_loss: 3.0851 - val_y2_output_loss: 6.0971 - val_y1_output_root_mean_squared_error: 1.7564 - val_y2_output_root_mean_squared_error: 2.4692
# Epoch 49/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.1274 - y1_output_loss: 3.3874 - y2_output_loss: 6.7400 - y1_output_root_mean_squared_error: 1.8312 - y2_output_root_mean_squared_error: 2.5805 - val_loss: 38.5763 - val_y1_output_loss: 7.0184 - val_y2_output_loss: 31.5578 - val_y1_output_root_mean_squared_error: 2.6492 - val_y2_output_root_mean_squared_error: 5.6176
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.0869 - y1_output_loss: 3.4849 - y2_output_loss: 8.6020 - y1_output_root_mean_squared_error: 1.8547 - y2_output_root_mean_squared_error: 2.8625 - val_loss: 11.8155 - val_y1_output_loss: 4.1166 - val_y2_output_loss: 7.6988 - val_y1_output_root_mean_squared_error: 2.0289 - val_y2_output_root_mean_squared_error: 2.7747
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1704 - y1_output_loss: 2.5942 - y2_output_loss: 4.5762 - y1_output_root_mean_squared_error: 1.6094 - y2_output_root_mean_squared_error: 2.1367 - val_loss: 17.1655 - val_y1_output_loss: 3.7645 - val_y2_output_loss: 13.4010 - val_y1_output_root_mean_squared_error: 1.9402 - val_y2_output_root_mean_squared_error: 3.6607
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7216 - y1_output_loss: 2.3706 - y2_output_loss: 4.3510 - y1_output_root_mean_squared_error: 1.5342 - y2_output_root_mean_squared_error: 2.0772 - val_loss: 12.5036 - val_y1_output_loss: 3.9760 - val_y2_output_loss: 8.5276 - val_y1_output_root_mean_squared_error: 1.9940 - val_y2_output_root_mean_squared_error: 2.9202
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7318 - y1_output_loss: 2.5187 - y2_output_loss: 5.2131 - y1_output_root_mean_squared_error: 1.5809 - y2_output_root_mean_squared_error: 2.2776 - val_loss: 8.2504 - val_y1_output_loss: 3.2181 - val_y2_output_loss: 5.0323 - val_y1_output_root_mean_squared_error: 1.7939 - val_y2_output_root_mean_squared_error: 2.2433
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7120 - y1_output_loss: 2.5030 - y2_output_loss: 4.2091 - y1_output_root_mean_squared_error: 1.5786 - y2_output_root_mean_squared_error: 2.0455 - val_loss: 10.8678 - val_y1_output_loss: 4.2007 - val_y2_output_loss: 6.6671 - val_y1_output_root_mean_squared_error: 2.0496 - val_y2_output_root_mean_squared_error: 2.5821
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.3132 - y1_output_loss: 2.4013 - y2_output_loss: 3.9119 - y1_output_root_mean_squared_error: 1.5440 - y2_output_root_mean_squared_error: 1.9700 - val_loss: 19.3671 - val_y1_output_loss: 5.6515 - val_y2_output_loss: 13.7156 - val_y1_output_root_mean_squared_error: 2.3773 - val_y2_output_root_mean_squared_error: 3.7035
# Epoch 56/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.9610 - y1_output_loss: 2.2256 - y2_output_loss: 4.7354 - y1_output_root_mean_squared_error: 1.4885 - y2_output_root_mean_squared_error: 2.1714 - val_loss: 8.4755 - val_y1_output_loss: 3.1779 - val_y2_output_loss: 5.2975 - val_y1_output_root_mean_squared_error: 1.7827 - val_y2_output_root_mean_squared_error: 2.3016
# Epoch 57/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7960 - y1_output_loss: 1.7863 - y2_output_loss: 4.0097 - y1_output_root_mean_squared_error: 1.3326 - y2_output_root_mean_squared_error: 2.0013 - val_loss: 10.3622 - val_y1_output_loss: 3.8078 - val_y2_output_loss: 6.5544 - val_y1_output_root_mean_squared_error: 1.9514 - val_y2_output_root_mean_squared_error: 2.5602
# Epoch 58/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2478 - y1_output_loss: 2.3798 - y2_output_loss: 4.8680 - y1_output_root_mean_squared_error: 1.5299 - y2_output_root_mean_squared_error: 2.1809 - val_loss: 7.9919 - val_y1_output_loss: 3.2520 - val_y2_output_loss: 4.7399 - val_y1_output_root_mean_squared_error: 1.8033 - val_y2_output_root_mean_squared_error: 2.1771
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1098 - y1_output_loss: 1.9756 - y2_output_loss: 4.1342 - y1_output_root_mean_squared_error: 1.4044 - y2_output_root_mean_squared_error: 2.0302 - val_loss: 6.8628 - val_y1_output_loss: 2.3502 - val_y2_output_loss: 4.5126 - val_y1_output_root_mean_squared_error: 1.5330 - val_y2_output_root_mean_squared_error: 2.1243
# Epoch 60/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7565 - y1_output_loss: 2.1319 - y2_output_loss: 4.6246 - y1_output_root_mean_squared_error: 1.4558 - y2_output_root_mean_squared_error: 2.1439 - val_loss: 7.4326 - val_y1_output_loss: 2.7388 - val_y2_output_loss: 4.6938 - val_y1_output_root_mean_squared_error: 1.6549 - val_y2_output_root_mean_squared_error: 2.1665
# Epoch 61/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6587 - y1_output_loss: 1.9082 - y2_output_loss: 3.7504 - y1_output_root_mean_squared_error: 1.3793 - y2_output_root_mean_squared_error: 1.9313 - val_loss: 10.7409 - val_y1_output_loss: 2.3225 - val_y2_output_loss: 8.4183 - val_y1_output_root_mean_squared_error: 1.5240 - val_y2_output_root_mean_squared_error: 2.9014
# Epoch 62/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.9639 - y1_output_loss: 2.1070 - y2_output_loss: 4.8569 - y1_output_root_mean_squared_error: 1.4503 - y2_output_root_mean_squared_error: 2.1963 - val_loss: 8.1713 - val_y1_output_loss: 1.9559 - val_y2_output_loss: 6.2154 - val_y1_output_root_mean_squared_error: 1.3985 - val_y2_output_root_mean_squared_error: 2.4931
# Epoch 63/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8863 - y1_output_loss: 2.3187 - y2_output_loss: 5.5676 - y1_output_root_mean_squared_error: 1.5206 - y2_output_root_mean_squared_error: 2.3445 - val_loss: 6.8849 - val_y1_output_loss: 2.4418 - val_y2_output_loss: 4.4431 - val_y1_output_root_mean_squared_error: 1.5626 - val_y2_output_root_mean_squared_error: 2.1079
# Epoch 64/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6804 - y1_output_loss: 1.8474 - y2_output_loss: 3.8331 - y1_output_root_mean_squared_error: 1.3551 - y2_output_root_mean_squared_error: 1.9523 - val_loss: 7.3520 - val_y1_output_loss: 2.1618 - val_y2_output_loss: 5.1902 - val_y1_output_root_mean_squared_error: 1.4703 - val_y2_output_root_mean_squared_error: 2.2782
# Epoch 65/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6717 - y1_output_loss: 1.6611 - y2_output_loss: 4.0107 - y1_output_root_mean_squared_error: 1.2837 - y2_output_root_mean_squared_error: 1.9963 - val_loss: 8.2542 - val_y1_output_loss: 3.2750 - val_y2_output_loss: 4.9792 - val_y1_output_root_mean_squared_error: 1.8097 - val_y2_output_root_mean_squared_error: 2.2314
# Epoch 66/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7624 - y1_output_loss: 1.8875 - y2_output_loss: 3.8749 - y1_output_root_mean_squared_error: 1.3713 - y2_output_root_mean_squared_error: 1.9660 - val_loss: 6.9801 - val_y1_output_loss: 2.5873 - val_y2_output_loss: 4.3928 - val_y1_output_root_mean_squared_error: 1.6085 - val_y2_output_root_mean_squared_error: 2.0959
# Epoch 67/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.2088 - y1_output_loss: 1.6079 - y2_output_loss: 3.6009 - y1_output_root_mean_squared_error: 1.2662 - y2_output_root_mean_squared_error: 1.8870 - val_loss: 10.8083 - val_y1_output_loss: 2.4242 - val_y2_output_loss: 8.3841 - val_y1_output_root_mean_squared_error: 1.5570 - val_y2_output_root_mean_squared_error: 2.8955
# Epoch 68/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1880 - y1_output_loss: 1.7449 - y2_output_loss: 4.4431 - y1_output_root_mean_squared_error: 1.3188 - y2_output_root_mean_squared_error: 2.0947 - val_loss: 5.6508 - val_y1_output_loss: 1.5834 - val_y2_output_loss: 4.0674 - val_y1_output_root_mean_squared_error: 1.2583 - val_y2_output_root_mean_squared_error: 2.0168
# Epoch 69/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0242 - y1_output_loss: 1.2602 - y2_output_loss: 2.7640 - y1_output_root_mean_squared_error: 1.1187 - y2_output_root_mean_squared_error: 1.6591 - val_loss: 7.0560 - val_y1_output_loss: 1.6230 - val_y2_output_loss: 5.4330 - val_y1_output_root_mean_squared_error: 1.2740 - val_y2_output_root_mean_squared_error: 2.3309
# Epoch 70/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.5543 - y1_output_loss: 1.7770 - y2_output_loss: 3.7773 - y1_output_root_mean_squared_error: 1.3309 - y2_output_root_mean_squared_error: 1.9374 - val_loss: 7.1916 - val_y1_output_loss: 2.1129 - val_y2_output_loss: 5.0787 - val_y1_output_root_mean_squared_error: 1.4536 - val_y2_output_root_mean_squared_error: 2.2536
# Epoch 71/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6947 - y1_output_loss: 1.6605 - y2_output_loss: 4.0341 - y1_output_root_mean_squared_error: 1.2851 - y2_output_root_mean_squared_error: 1.9884 - val_loss: 5.7483 - val_y1_output_loss: 1.7773 - val_y2_output_loss: 3.9711 - val_y1_output_root_mean_squared_error: 1.3331 - val_y2_output_root_mean_squared_error: 1.9928
# Epoch 72/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.8634 - y1_output_loss: 1.3608 - y2_output_loss: 3.5027 - y1_output_root_mean_squared_error: 1.1640 - y2_output_root_mean_squared_error: 1.8628 - val_loss: 14.8535 - val_y1_output_loss: 2.5783 - val_y2_output_loss: 12.2753 - val_y1_output_root_mean_squared_error: 1.6057 - val_y2_output_root_mean_squared_error: 3.5036
# Epoch 73/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.0798 - y1_output_loss: 2.6223 - y2_output_loss: 6.4575 - y1_output_root_mean_squared_error: 1.5805 - y2_output_root_mean_squared_error: 2.4622 - val_loss: 5.4988 - val_y1_output_loss: 1.6489 - val_y2_output_loss: 3.8499 - val_y1_output_root_mean_squared_error: 1.2841 - val_y2_output_root_mean_squared_error: 1.9621
# Epoch 74/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.4635 - y1_output_loss: 1.4549 - y2_output_loss: 4.0087 - y1_output_root_mean_squared_error: 1.2036 - y2_output_root_mean_squared_error: 1.9992 - val_loss: 10.0950 - val_y1_output_loss: 2.6426 - val_y2_output_loss: 7.4524 - val_y1_output_root_mean_squared_error: 1.6256 - val_y2_output_root_mean_squared_error: 2.7299
# Epoch 75/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.4386 - y1_output_loss: 1.7493 - y2_output_loss: 3.6893 - y1_output_root_mean_squared_error: 1.3158 - y2_output_root_mean_squared_error: 1.9052 - val_loss: 9.7296 - val_y1_output_loss: 1.6684 - val_y2_output_loss: 8.0612 - val_y1_output_root_mean_squared_error: 1.2917 - val_y2_output_root_mean_squared_error: 2.8392
# Epoch 76/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0562 - y1_output_loss: 1.1125 - y2_output_loss: 2.9438 - y1_output_root_mean_squared_error: 1.0541 - y2_output_root_mean_squared_error: 1.7123 - val_loss: 8.2294 - val_y1_output_loss: 2.3730 - val_y2_output_loss: 5.8564 - val_y1_output_root_mean_squared_error: 1.5405 - val_y2_output_root_mean_squared_error: 2.4200
# Epoch 77/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.0801 - y1_output_loss: 1.4824 - y2_output_loss: 3.5976 - y1_output_root_mean_squared_error: 1.2160 - y2_output_root_mean_squared_error: 1.8911 - val_loss: 5.3238 - val_y1_output_loss: 1.1467 - val_y2_output_loss: 4.1771 - val_y1_output_root_mean_squared_error: 1.0708 - val_y2_output_root_mean_squared_error: 2.0438
# Epoch 78/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8637 - y1_output_loss: 1.2873 - y2_output_loss: 2.5764 - y1_output_root_mean_squared_error: 1.1334 - y2_output_root_mean_squared_error: 1.6031 - val_loss: 4.7206 - val_y1_output_loss: 1.4823 - val_y2_output_loss: 3.2383 - val_y1_output_root_mean_squared_error: 1.2175 - val_y2_output_root_mean_squared_error: 1.7995
# Epoch 79/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2438 - y1_output_loss: 1.3209 - y2_output_loss: 2.9229 - y1_output_root_mean_squared_error: 1.1453 - y2_output_root_mean_squared_error: 1.6937 - val_loss: 7.1462 - val_y1_output_loss: 1.8467 - val_y2_output_loss: 5.2995 - val_y1_output_root_mean_squared_error: 1.3589 - val_y2_output_root_mean_squared_error: 2.3021
# Epoch 80/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.1214 - y1_output_loss: 1.5133 - y2_output_loss: 3.6081 - y1_output_root_mean_squared_error: 1.2224 - y2_output_root_mean_squared_error: 1.8787 - val_loss: 4.8145 - val_y1_output_loss: 1.4249 - val_y2_output_loss: 3.3896 - val_y1_output_root_mean_squared_error: 1.1937 - val_y2_output_root_mean_squared_error: 1.8411
# Epoch 81/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.5584 - y1_output_loss: 1.5876 - y2_output_loss: 2.9708 - y1_output_root_mean_squared_error: 1.2488 - y2_output_root_mean_squared_error: 1.7167 - val_loss: 4.6645 - val_y1_output_loss: 1.3022 - val_y2_output_loss: 3.3623 - val_y1_output_root_mean_squared_error: 1.1411 - val_y2_output_root_mean_squared_error: 1.8337
# Epoch 82/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.3442 - y1_output_loss: 1.2989 - y2_output_loss: 3.0453 - y1_output_root_mean_squared_error: 1.1368 - y2_output_root_mean_squared_error: 1.7427 - val_loss: 7.6173 - val_y1_output_loss: 1.9799 - val_y2_output_loss: 5.6375 - val_y1_output_root_mean_squared_error: 1.4071 - val_y2_output_root_mean_squared_error: 2.3743
# Epoch 83/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2996 - y1_output_loss: 1.4943 - y2_output_loss: 2.8053 - y1_output_root_mean_squared_error: 1.2164 - y2_output_root_mean_squared_error: 1.6691 - val_loss: 3.8136 - val_y1_output_loss: 0.9588 - val_y2_output_loss: 2.8549 - val_y1_output_root_mean_squared_error: 0.9792 - val_y2_output_root_mean_squared_error: 1.6896
# Epoch 84/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7898 - y1_output_loss: 1.1197 - y2_output_loss: 2.6701 - y1_output_root_mean_squared_error: 1.0568 - y2_output_root_mean_squared_error: 1.6321 - val_loss: 4.1149 - val_y1_output_loss: 1.0222 - val_y2_output_loss: 3.0927 - val_y1_output_root_mean_squared_error: 1.0111 - val_y2_output_root_mean_squared_error: 1.7586
# Epoch 85/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8161 - y1_output_loss: 1.1533 - y2_output_loss: 2.6629 - y1_output_root_mean_squared_error: 1.0728 - y2_output_root_mean_squared_error: 1.6305 - val_loss: 7.7718 - val_y1_output_loss: 1.5995 - val_y2_output_loss: 6.1723 - val_y1_output_root_mean_squared_error: 1.2647 - val_y2_output_root_mean_squared_error: 2.4844
# Epoch 86/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1727 - y1_output_loss: 1.6566 - y2_output_loss: 4.5161 - y1_output_root_mean_squared_error: 1.2798 - y2_output_root_mean_squared_error: 2.1028 - val_loss: 5.6513 - val_y1_output_loss: 1.3507 - val_y2_output_loss: 4.3007 - val_y1_output_root_mean_squared_error: 1.1622 - val_y2_output_root_mean_squared_error: 2.0738
# Epoch 87/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7375 - y1_output_loss: 1.2361 - y2_output_loss: 2.5015 - y1_output_root_mean_squared_error: 1.1099 - y2_output_root_mean_squared_error: 1.5766 - val_loss: 4.8527 - val_y1_output_loss: 1.4153 - val_y2_output_loss: 3.4374 - val_y1_output_root_mean_squared_error: 1.1897 - val_y2_output_root_mean_squared_error: 1.8540
# Epoch 88/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.1717 - y1_output_loss: 0.9671 - y2_output_loss: 2.2046 - y1_output_root_mean_squared_error: 0.9803 - y2_output_root_mean_squared_error: 1.4783 - val_loss: 6.4606 - val_y1_output_loss: 1.0048 - val_y2_output_loss: 5.4558 - val_y1_output_root_mean_squared_error: 1.0024 - val_y2_output_root_mean_squared_error: 2.3358
# Epoch 89/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8300 - y1_output_loss: 0.9055 - y2_output_loss: 2.9245 - y1_output_root_mean_squared_error: 0.9466 - y2_output_root_mean_squared_error: 1.7041 - val_loss: 7.6643 - val_y1_output_loss: 2.0072 - val_y2_output_loss: 5.6571 - val_y1_output_root_mean_squared_error: 1.4168 - val_y2_output_root_mean_squared_error: 2.3785
# Epoch 90/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.1851 - y1_output_loss: 1.7823 - y2_output_loss: 3.4028 - y1_output_root_mean_squared_error: 1.3254 - y2_output_root_mean_squared_error: 1.8359 - val_loss: 6.2126 - val_y1_output_loss: 1.6530 - val_y2_output_loss: 4.5596 - val_y1_output_root_mean_squared_error: 1.2857 - val_y2_output_root_mean_squared_error: 2.1353
# Epoch 91/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7508 - y1_output_loss: 1.1051 - y2_output_loss: 2.6458 - y1_output_root_mean_squared_error: 1.0440 - y2_output_root_mean_squared_error: 1.6223 - val_loss: 9.8168 - val_y1_output_loss: 3.1038 - val_y2_output_loss: 6.7129 - val_y1_output_root_mean_squared_error: 1.7618 - val_y2_output_root_mean_squared_error: 2.5909
# Epoch 92/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0297 - y1_output_loss: 0.9329 - y2_output_loss: 2.0969 - y1_output_root_mean_squared_error: 0.9617 - y2_output_root_mean_squared_error: 1.4451 - val_loss: 6.9165 - val_y1_output_loss: 0.7776 - val_y2_output_loss: 6.1389 - val_y1_output_root_mean_squared_error: 0.8818 - val_y2_output_root_mean_squared_error: 2.4777
# Epoch 93/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.7237 - y1_output_loss: 1.3185 - y2_output_loss: 3.4053 - y1_output_root_mean_squared_error: 1.1401 - y2_output_root_mean_squared_error: 1.8274 - val_loss: 3.5291 - val_y1_output_loss: 0.8810 - val_y2_output_loss: 2.6482 - val_y1_output_root_mean_squared_error: 0.9386 - val_y2_output_root_mean_squared_error: 1.6273
# Epoch 94/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.1881 - y1_output_loss: 1.2504 - y2_output_loss: 2.9377 - y1_output_root_mean_squared_error: 1.1060 - y2_output_root_mean_squared_error: 1.6945 - val_loss: 4.4975 - val_y1_output_loss: 1.1848 - val_y2_output_loss: 3.3127 - val_y1_output_root_mean_squared_error: 1.0885 - val_y2_output_root_mean_squared_error: 1.8201
# Epoch 95/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.8523 - y1_output_loss: 1.3951 - y2_output_loss: 3.4571 - y1_output_root_mean_squared_error: 1.1333 - y2_output_root_mean_squared_error: 1.7932 - val_loss: 6.8194 - val_y1_output_loss: 1.4656 - val_y2_output_loss: 5.3538 - val_y1_output_root_mean_squared_error: 1.2106 - val_y2_output_root_mean_squared_error: 2.3138
# Epoch 96/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.8347 - y1_output_loss: 1.8627 - y2_output_loss: 3.9721 - y1_output_root_mean_squared_error: 1.3564 - y2_output_root_mean_squared_error: 1.9505 - val_loss: 5.7060 - val_y1_output_loss: 1.2218 - val_y2_output_loss: 4.4841 - val_y1_output_root_mean_squared_error: 1.1054 - val_y2_output_root_mean_squared_error: 2.1176
# Epoch 97/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.6623 - y1_output_loss: 0.9395 - y2_output_loss: 2.7228 - y1_output_root_mean_squared_error: 0.9623 - y2_output_root_mean_squared_error: 1.6474 - val_loss: 14.4530 - val_y1_output_loss: 3.1118 - val_y2_output_loss: 11.3412 - val_y1_output_root_mean_squared_error: 1.7640 - val_y2_output_root_mean_squared_error: 3.3677
# Epoch 98/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.3072 - y1_output_loss: 1.2892 - y2_output_loss: 3.0180 - y1_output_root_mean_squared_error: 1.1157 - y2_output_root_mean_squared_error: 1.7173 - val_loss: 9.1616 - val_y1_output_loss: 1.8715 - val_y2_output_loss: 7.2901 - val_y1_output_root_mean_squared_error: 1.3680 - val_y2_output_root_mean_squared_error: 2.7000
# Epoch 99/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.1026 - y1_output_loss: 1.4676 - y2_output_loss: 3.6350 - y1_output_root_mean_squared_error: 1.1979 - y2_output_root_mean_squared_error: 1.8896 - val_loss: 3.8800 - val_y1_output_loss: 0.9129 - val_y2_output_loss: 2.9671 - val_y1_output_root_mean_squared_error: 0.9555 - val_y2_output_root_mean_squared_error: 1.7225
# Epoch 100/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0819 - y1_output_loss: 0.8356 - y2_output_loss: 2.2463 - y1_output_root_mean_squared_error: 0.9125 - y2_output_root_mean_squared_error: 1.4924 - val_loss: 4.7686 - val_y1_output_loss: 1.2067 - val_y2_output_loss: 3.5618 - val_y1_output_root_mean_squared_error: 1.0985 - val_y2_output_root_mean_squared_error: 1.8873
# Epoch 101/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0432 - y1_output_loss: 0.8882 - y2_output_loss: 2.1551 - y1_output_root_mean_squared_error: 0.9403 - y2_output_root_mean_squared_error: 1.4656 - val_loss: 5.0994 - val_y1_output_loss: 1.4268 - val_y2_output_loss: 3.6726 - val_y1_output_root_mean_squared_error: 1.1945 - val_y2_output_root_mean_squared_error: 1.9164
# Epoch 102/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.6066 - y1_output_loss: 0.9820 - y2_output_loss: 2.6246 - y1_output_root_mean_squared_error: 0.9882 - y2_output_root_mean_squared_error: 1.6141 - val_loss: 6.6899 - val_y1_output_loss: 2.1190 - val_y2_output_loss: 4.5709 - val_y1_output_root_mean_squared_error: 1.4557 - val_y2_output_root_mean_squared_error: 2.1380
# Epoch 103/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3243 - y1_output_loss: 0.9146 - y2_output_loss: 2.4097 - y1_output_root_mean_squared_error: 0.9508 - y2_output_root_mean_squared_error: 1.5484 - val_loss: 4.5042 - val_y1_output_loss: 1.7426 - val_y2_output_loss: 2.7616 - val_y1_output_root_mean_squared_error: 1.3201 - val_y2_output_root_mean_squared_error: 1.6618
# Epoch 104/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6640 - y1_output_loss: 0.7427 - y2_output_loss: 1.9213 - y1_output_root_mean_squared_error: 0.8587 - y2_output_root_mean_squared_error: 1.3841 - val_loss: 4.0346 - val_y1_output_loss: 1.1389 - val_y2_output_loss: 2.8957 - val_y1_output_root_mean_squared_error: 1.0672 - val_y2_output_root_mean_squared_error: 1.7017
# Epoch 105/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.4507 - y1_output_loss: 0.7235 - y2_output_loss: 1.7273 - y1_output_root_mean_squared_error: 0.8489 - y2_output_root_mean_squared_error: 1.3124 - val_loss: 4.1134 - val_y1_output_loss: 0.9480 - val_y2_output_loss: 3.1653 - val_y1_output_root_mean_squared_error: 0.9737 - val_y2_output_root_mean_squared_error: 1.7791
# Epoch 106/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.5404 - y1_output_loss: 0.9530 - y2_output_loss: 2.5874 - y1_output_root_mean_squared_error: 0.9719 - y2_output_root_mean_squared_error: 1.6054 - val_loss: 3.8600 - val_y1_output_loss: 0.7654 - val_y2_output_loss: 3.0946 - val_y1_output_root_mean_squared_error: 0.8749 - val_y2_output_root_mean_squared_error: 1.7591
# Epoch 107/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9216 - y1_output_loss: 0.4582 - y2_output_loss: 1.4634 - y1_output_root_mean_squared_error: 0.6736 - y2_output_root_mean_squared_error: 1.2029 - val_loss: 5.5786 - val_y1_output_loss: 0.8070 - val_y2_output_loss: 4.7716 - val_y1_output_root_mean_squared_error: 0.8983 - val_y2_output_root_mean_squared_error: 2.1844
# Epoch 108/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8300 - y1_output_loss: 0.6751 - y2_output_loss: 2.1549 - y1_output_root_mean_squared_error: 0.8198 - y2_output_root_mean_squared_error: 1.4671 - val_loss: 5.6537 - val_y1_output_loss: 1.8379 - val_y2_output_loss: 3.8158 - val_y1_output_root_mean_squared_error: 1.3557 - val_y2_output_root_mean_squared_error: 1.9534
# Epoch 109/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6874 - y1_output_loss: 0.6426 - y2_output_loss: 2.0448 - y1_output_root_mean_squared_error: 0.8006 - y2_output_root_mean_squared_error: 1.4207 - val_loss: 3.3970 - val_y1_output_loss: 0.7889 - val_y2_output_loss: 2.6081 - val_y1_output_root_mean_squared_error: 0.8882 - val_y2_output_root_mean_squared_error: 1.6150
# Epoch 110/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0577 - y1_output_loss: 0.7268 - y2_output_loss: 2.3308 - y1_output_root_mean_squared_error: 0.8502 - y2_output_root_mean_squared_error: 1.5210 - val_loss: 5.2559 - val_y1_output_loss: 1.6621 - val_y2_output_loss: 3.5938 - val_y1_output_root_mean_squared_error: 1.2892 - val_y2_output_root_mean_squared_error: 1.8957
# Epoch 111/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8085 - y1_output_loss: 0.7540 - y2_output_loss: 2.0545 - y1_output_root_mean_squared_error: 0.8666 - y2_output_root_mean_squared_error: 1.4299 - val_loss: 16.2046 - val_y1_output_loss: 3.7153 - val_y2_output_loss: 12.4893 - val_y1_output_root_mean_squared_error: 1.9275 - val_y2_output_root_mean_squared_error: 3.5340
# Epoch 112/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2582 - y1_output_loss: 1.0863 - y2_output_loss: 3.1720 - y1_output_root_mean_squared_error: 1.0163 - y2_output_root_mean_squared_error: 1.7340 - val_loss: 3.5646 - val_y1_output_loss: 0.6433 - val_y2_output_loss: 2.9213 - val_y1_output_root_mean_squared_error: 0.8021 - val_y2_output_root_mean_squared_error: 1.7092
# Epoch 113/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.4852 - y1_output_loss: 1.0496 - y2_output_loss: 2.4355 - y1_output_root_mean_squared_error: 1.0207 - y2_output_root_mean_squared_error: 1.5465 - val_loss: 3.2333 - val_y1_output_loss: 0.6028 - val_y2_output_loss: 2.6305 - val_y1_output_root_mean_squared_error: 0.7764 - val_y2_output_root_mean_squared_error: 1.6219
# Epoch 114/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9605 - y1_output_loss: 0.4869 - y2_output_loss: 1.4736 - y1_output_root_mean_squared_error: 0.6953 - y2_output_root_mean_squared_error: 1.2110 - val_loss: 4.0465 - val_y1_output_loss: 0.9894 - val_y2_output_loss: 3.0570 - val_y1_output_root_mean_squared_error: 0.9947 - val_y2_output_root_mean_squared_error: 1.7484
# Epoch 115/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3933 - y1_output_loss: 0.6298 - y2_output_loss: 1.7635 - y1_output_root_mean_squared_error: 0.7922 - y2_output_root_mean_squared_error: 1.3261 - val_loss: 5.4009 - val_y1_output_loss: 1.3338 - val_y2_output_loss: 4.0672 - val_y1_output_root_mean_squared_error: 1.1549 - val_y2_output_root_mean_squared_error: 2.0167
# Epoch 116/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3858 - y1_output_loss: 0.6656 - y2_output_loss: 1.7202 - y1_output_root_mean_squared_error: 0.8112 - y2_output_root_mean_squared_error: 1.3048 - val_loss: 8.7195 - val_y1_output_loss: 1.0664 - val_y2_output_loss: 7.6531 - val_y1_output_root_mean_squared_error: 1.0327 - val_y2_output_root_mean_squared_error: 2.7664
# Epoch 117/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5193 - y1_output_loss: 0.6405 - y2_output_loss: 1.8787 - y1_output_root_mean_squared_error: 0.7985 - y2_output_root_mean_squared_error: 1.3662 - val_loss: 5.8735 - val_y1_output_loss: 1.4087 - val_y2_output_loss: 4.4648 - val_y1_output_root_mean_squared_error: 1.1869 - val_y2_output_root_mean_squared_error: 2.1130
# Epoch 118/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.1456 - y1_output_loss: 0.5671 - y2_output_loss: 1.5784 - y1_output_root_mean_squared_error: 0.7504 - y2_output_root_mean_squared_error: 1.2538 - val_loss: 6.5953 - val_y1_output_loss: 1.7832 - val_y2_output_loss: 4.8121 - val_y1_output_root_mean_squared_error: 1.3354 - val_y2_output_root_mean_squared_error: 2.1936
# Epoch 119/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0163 - y1_output_loss: 0.8897 - y2_output_loss: 2.1266 - y1_output_root_mean_squared_error: 0.9218 - y2_output_root_mean_squared_error: 1.4240 - val_loss: 4.7226 - val_y1_output_loss: 0.9789 - val_y2_output_loss: 3.7437 - val_y1_output_root_mean_squared_error: 0.9894 - val_y2_output_root_mean_squared_error: 1.9349
# Epoch 120/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.0135 - y1_output_loss: 0.5328 - y2_output_loss: 1.4806 - y1_output_root_mean_squared_error: 0.7294 - y2_output_root_mean_squared_error: 1.2160 - val_loss: 5.0225 - val_y1_output_loss: 1.5342 - val_y2_output_loss: 3.4883 - val_y1_output_root_mean_squared_error: 1.2386 - val_y2_output_root_mean_squared_error: 1.8677
# Epoch 121/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.4687 - y1_output_loss: 1.5001 - y2_output_loss: 3.9685 - y1_output_root_mean_squared_error: 1.1912 - y2_output_root_mean_squared_error: 1.9402 - val_loss: 30.6122 - val_y1_output_loss: 8.2625 - val_y2_output_loss: 22.3497 - val_y1_output_root_mean_squared_error: 2.8745 - val_y2_output_root_mean_squared_error: 4.7275
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4633 - y1_output_loss: 0.1328 - y2_output_loss: 0.3305 - y1_output_root_mean_squared_error: 0.3638 - y2_output_root_mean_squared_error: 0.5726 - val_loss: 1.2729 - val_y1_output_loss: 0.2947 - val_y2_output_loss: 0.9783 - val_y1_output_root_mean_squared_error: 0.5429 - val_y2_output_root_mean_squared_error: 0.9891
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3571 - y1_output_loss: 0.1143 - y2_output_loss: 0.2428 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.4901 - val_loss: 2.2804 - val_y1_output_loss: 0.4075 - val_y2_output_loss: 1.8729 - val_y1_output_root_mean_squared_error: 0.6384 - val_y2_output_root_mean_squared_error: 1.3685
# Epoch 463/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6829 - y1_output_loss: 0.1864 - y2_output_loss: 0.4964 - y1_output_root_mean_squared_error: 0.4265 - y2_output_root_mean_squared_error: 0.6821 - val_loss: 1.2769 - val_y1_output_loss: 0.3099 - val_y2_output_loss: 0.9671 - val_y1_output_root_mean_squared_error: 0.5567 - val_y2_output_root_mean_squared_error: 0.9834
# Epoch 464/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3132 - y1_output_loss: 0.1051 - y2_output_loss: 0.2082 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.4555 - val_loss: 1.3494 - val_y1_output_loss: 0.2608 - val_y2_output_loss: 1.0886 - val_y1_output_root_mean_squared_error: 0.5107 - val_y2_output_root_mean_squared_error: 1.0433
# Epoch 465/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4530 - y1_output_loss: 0.1385 - y2_output_loss: 0.3144 - y1_output_root_mean_squared_error: 0.3712 - y2_output_root_mean_squared_error: 0.5600 - val_loss: 1.3097 - val_y1_output_loss: 0.2283 - val_y2_output_loss: 1.0814 - val_y1_output_root_mean_squared_error: 0.4778 - val_y2_output_root_mean_squared_error: 1.0399
# Epoch 466/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5167 - y1_output_loss: 0.1499 - y2_output_loss: 0.3668 - y1_output_root_mean_squared_error: 0.3846 - y2_output_root_mean_squared_error: 0.6030 - val_loss: 1.3567 - val_y1_output_loss: 0.2498 - val_y2_output_loss: 1.1069 - val_y1_output_root_mean_squared_error: 0.4998 - val_y2_output_root_mean_squared_error: 1.0521
# Epoch 467/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3684 - y1_output_loss: 0.0932 - y2_output_loss: 0.2752 - y1_output_root_mean_squared_error: 0.3050 - y2_output_root_mean_squared_error: 0.5237 - val_loss: 1.4413 - val_y1_output_loss: 0.3304 - val_y2_output_loss: 1.1108 - val_y1_output_root_mean_squared_error: 0.5748 - val_y2_output_root_mean_squared_error: 1.0540
# Epoch 468/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4557 - y1_output_loss: 0.1140 - y2_output_loss: 0.3416 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.5833 - val_loss: 1.9444 - val_y1_output_loss: 0.3054 - val_y2_output_loss: 1.6390 - val_y1_output_root_mean_squared_error: 0.5526 - val_y2_output_root_mean_squared_error: 1.2802
# Epoch 469/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6528 - y1_output_loss: 0.1550 - y2_output_loss: 0.4978 - y1_output_root_mean_squared_error: 0.3924 - y2_output_root_mean_squared_error: 0.7000 - val_loss: 1.4892 - val_y1_output_loss: 0.2714 - val_y2_output_loss: 1.2178 - val_y1_output_root_mean_squared_error: 0.5210 - val_y2_output_root_mean_squared_error: 1.1035
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4320 - y1_output_loss: 0.1125 - y2_output_loss: 0.3195 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5633 - val_loss: 2.7209 - val_y1_output_loss: 0.5439 - val_y2_output_loss: 2.1771 - val_y1_output_root_mean_squared_error: 0.7375 - val_y2_output_root_mean_squared_error: 1.4755
# Epoch 471/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.2109 - y1_output_loss: 0.2755 - y2_output_loss: 0.9354 - y1_output_root_mean_squared_error: 0.5138 - y2_output_root_mean_squared_error: 0.9366 - val_loss: 1.3367 - val_y1_output_loss: 0.2486 - val_y2_output_loss: 1.0881 - val_y1_output_root_mean_squared_error: 0.4986 - val_y2_output_root_mean_squared_error: 1.0431
# Epoch 472/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4048 - y1_output_loss: 0.1231 - y2_output_loss: 0.2817 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.5283 - val_loss: 1.8822 - val_y1_output_loss: 0.4587 - val_y2_output_loss: 1.4234 - val_y1_output_root_mean_squared_error: 0.6773 - val_y2_output_root_mean_squared_error: 1.1931
# Epoch 473/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5515 - y1_output_loss: 0.1880 - y2_output_loss: 0.3635 - y1_output_root_mean_squared_error: 0.4267 - y2_output_root_mean_squared_error: 0.6005 - val_loss: 1.4834 - val_y1_output_loss: 0.2873 - val_y2_output_loss: 1.1961 - val_y1_output_root_mean_squared_error: 0.5360 - val_y2_output_root_mean_squared_error: 1.0937
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3346 - y1_output_loss: 0.0920 - y2_output_loss: 0.2427 - y1_output_root_mean_squared_error: 0.3028 - y2_output_root_mean_squared_error: 0.4906 - val_loss: 1.1797 - val_y1_output_loss: 0.2254 - val_y2_output_loss: 0.9543 - val_y1_output_root_mean_squared_error: 0.4748 - val_y2_output_root_mean_squared_error: 0.9769
# Epoch 475/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3814 - y1_output_loss: 0.0983 - y2_output_loss: 0.2831 - y1_output_root_mean_squared_error: 0.3130 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 1.2483 - val_y1_output_loss: 0.2989 - val_y2_output_loss: 0.9494 - val_y1_output_root_mean_squared_error: 0.5467 - val_y2_output_root_mean_squared_error: 0.9744
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3413 - y1_output_loss: 0.1137 - y2_output_loss: 0.2277 - y1_output_root_mean_squared_error: 0.3361 - y2_output_root_mean_squared_error: 0.4762 - val_loss: 1.2482 - val_y1_output_loss: 0.2229 - val_y2_output_loss: 1.0253 - val_y1_output_root_mean_squared_error: 0.4721 - val_y2_output_root_mean_squared_error: 1.0126
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3292 - y1_output_loss: 0.1023 - y2_output_loss: 0.2270 - y1_output_root_mean_squared_error: 0.3188 - y2_output_root_mean_squared_error: 0.4746 - val_loss: 1.5588 - val_y1_output_loss: 0.2330 - val_y2_output_loss: 1.3258 - val_y1_output_root_mean_squared_error: 0.4827 - val_y2_output_root_mean_squared_error: 1.1514
# Epoch 478/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3741 - y1_output_loss: 0.1191 - y2_output_loss: 0.2550 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5014 - val_loss: 1.3345 - val_y1_output_loss: 0.3809 - val_y2_output_loss: 0.9537 - val_y1_output_root_mean_squared_error: 0.6172 - val_y2_output_root_mean_squared_error: 0.9766
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3770 - y1_output_loss: 0.1177 - y2_output_loss: 0.2593 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.5081 - val_loss: 1.3016 - val_y1_output_loss: 0.2369 - val_y2_output_loss: 1.0647 - val_y1_output_root_mean_squared_error: 0.4867 - val_y2_output_root_mean_squared_error: 1.0318
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5131 - y1_output_loss: 0.1573 - y2_output_loss: 0.3557 - y1_output_root_mean_squared_error: 0.3937 - y2_output_root_mean_squared_error: 0.5930 - val_loss: 1.2773 - val_y1_output_loss: 0.2962 - val_y2_output_loss: 0.9811 - val_y1_output_root_mean_squared_error: 0.5443 - val_y2_output_root_mean_squared_error: 0.9905
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3562 - y1_output_loss: 0.1132 - y2_output_loss: 0.2430 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4927 - val_loss: 1.4635 - val_y1_output_loss: 0.2250 - val_y2_output_loss: 1.2385 - val_y1_output_root_mean_squared_error: 0.4743 - val_y2_output_root_mean_squared_error: 1.1129
# Epoch 482/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3430 - y1_output_loss: 0.1070 - y2_output_loss: 0.2360 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.4853 - val_loss: 2.3190 - val_y1_output_loss: 0.3865 - val_y2_output_loss: 1.9325 - val_y1_output_root_mean_squared_error: 0.6217 - val_y2_output_root_mean_squared_error: 1.3901
# Epoch 483/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7327 - y1_output_loss: 0.1771 - y2_output_loss: 0.5556 - y1_output_root_mean_squared_error: 0.4188 - y2_output_root_mean_squared_error: 0.7426 - val_loss: 1.4036 - val_y1_output_loss: 0.2604 - val_y2_output_loss: 1.1431 - val_y1_output_root_mean_squared_error: 0.5103 - val_y2_output_root_mean_squared_error: 1.0692
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4563 - y1_output_loss: 0.1497 - y2_output_loss: 0.3066 - y1_output_root_mean_squared_error: 0.3837 - y2_output_root_mean_squared_error: 0.5514 - val_loss: 1.2268 - val_y1_output_loss: 0.2191 - val_y2_output_loss: 1.0077 - val_y1_output_root_mean_squared_error: 0.4680 - val_y2_output_root_mean_squared_error: 1.0038
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3408 - y1_output_loss: 0.1053 - y2_output_loss: 0.2355 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.4845 - val_loss: 1.4541 - val_y1_output_loss: 0.2456 - val_y2_output_loss: 1.2086 - val_y1_output_root_mean_squared_error: 0.4955 - val_y2_output_root_mean_squared_error: 1.0994
# Epoch 486/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4283 - y1_output_loss: 0.1161 - y2_output_loss: 0.3121 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.5522 - val_loss: 1.6166 - val_y1_output_loss: 0.3043 - val_y2_output_loss: 1.3124 - val_y1_output_root_mean_squared_error: 0.5516 - val_y2_output_root_mean_squared_error: 1.1456
# Epoch 487/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3804 - y1_output_loss: 0.1060 - y2_output_loss: 0.2743 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.5209 - val_loss: 1.4533 - val_y1_output_loss: 0.3420 - val_y2_output_loss: 1.1113 - val_y1_output_root_mean_squared_error: 0.5848 - val_y2_output_root_mean_squared_error: 1.0542
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3720 - y1_output_loss: 0.1194 - y2_output_loss: 0.2526 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5017 - val_loss: 2.9455 - val_y1_output_loss: 0.7417 - val_y2_output_loss: 2.2037 - val_y1_output_root_mean_squared_error: 0.8612 - val_y2_output_root_mean_squared_error: 1.4845
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5177 - y1_output_loss: 0.1316 - y2_output_loss: 0.3861 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.6184 - val_loss: 1.3287 - val_y1_output_loss: 0.2747 - val_y2_output_loss: 1.0539 - val_y1_output_root_mean_squared_error: 0.5242 - val_y2_output_root_mean_squared_error: 1.0266
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3513 - y1_output_loss: 0.1165 - y2_output_loss: 0.2348 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4840 - val_loss: 1.2331 - val_y1_output_loss: 0.2502 - val_y2_output_loss: 0.9829 - val_y1_output_root_mean_squared_error: 0.5002 - val_y2_output_root_mean_squared_error: 0.9914
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5592 - y1_output_loss: 0.1519 - y2_output_loss: 0.4073 - y1_output_root_mean_squared_error: 0.3873 - y2_output_root_mean_squared_error: 0.6315 - val_loss: 1.6433 - val_y1_output_loss: 0.3495 - val_y2_output_loss: 1.2937 - val_y1_output_root_mean_squared_error: 0.5912 - val_y2_output_root_mean_squared_error: 1.1374
# Epoch 492/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3968 - y1_output_loss: 0.1110 - y2_output_loss: 0.2859 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.5306 - val_loss: 4.1831 - val_y1_output_loss: 1.1796 - val_y2_output_loss: 3.0035 - val_y1_output_root_mean_squared_error: 1.0861 - val_y2_output_root_mean_squared_error: 1.7330
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6266 - y1_output_loss: 0.1743 - y2_output_loss: 0.4523 - y1_output_root_mean_squared_error: 0.4102 - y2_output_root_mean_squared_error: 0.6553 - val_loss: 1.3085 - val_y1_output_loss: 0.2437 - val_y2_output_loss: 1.0647 - val_y1_output_root_mean_squared_error: 0.4937 - val_y2_output_root_mean_squared_error: 1.0319
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3365 - y1_output_loss: 0.1042 - y2_output_loss: 0.2323 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.4725 - val_loss: 1.4378 - val_y1_output_loss: 0.2951 - val_y2_output_loss: 1.1427 - val_y1_output_root_mean_squared_error: 0.5432 - val_y2_output_root_mean_squared_error: 1.0690
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3527 - y1_output_loss: 0.1147 - y2_output_loss: 0.2380 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.4830 - val_loss: 1.5212 - val_y1_output_loss: 0.2837 - val_y2_output_loss: 1.2374 - val_y1_output_root_mean_squared_error: 0.5327 - val_y2_output_root_mean_squared_error: 1.1124
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3544 - y1_output_loss: 0.1023 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3190 - y2_output_root_mean_squared_error: 0.4999 - val_loss: 1.3591 - val_y1_output_loss: 0.2532 - val_y2_output_loss: 1.1059 - val_y1_output_root_mean_squared_error: 0.5032 - val_y2_output_root_mean_squared_error: 1.0516
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3510 - y1_output_loss: 0.1166 - y2_output_loss: 0.2344 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.4838 - val_loss: 2.5579 - val_y1_output_loss: 0.2773 - val_y2_output_loss: 2.2806 - val_y1_output_root_mean_squared_error: 0.5265 - val_y2_output_root_mean_squared_error: 1.5102
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6069 - y1_output_loss: 0.2030 - y2_output_loss: 0.4039 - y1_output_root_mean_squared_error: 0.4409 - y2_output_root_mean_squared_error: 0.6212 - val_loss: 1.1639 - val_y1_output_loss: 0.2028 - val_y2_output_loss: 0.9610 - val_y1_output_root_mean_squared_error: 0.4504 - val_y2_output_root_mean_squared_error: 0.9803
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3248 - y1_output_loss: 0.0924 - y2_output_loss: 0.2324 - y1_output_root_mean_squared_error: 0.3022 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 3.2312 - val_y1_output_loss: 0.5930 - val_y2_output_loss: 2.6383 - val_y1_output_root_mean_squared_error: 0.7701 - val_y2_output_root_mean_squared_error: 1.6243
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5307 - y1_output_loss: 0.1777 - y2_output_loss: 0.3530 - y1_output_root_mean_squared_error: 0.4145 - y2_output_root_mean_squared_error: 0.5891 - val_loss: 1.3884 - val_y1_output_loss: 0.2584 - val_y2_output_loss: 1.1299 - val_y1_output_root_mean_squared_error: 0.5084 - val_y2_output_root_mean_squared_error: 1.0630

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3884 - y1_output_loss: 0.2584 - y2_output_loss: 1.1299 - y1_output_root_mean_squared_error: 0.5084 - y2_output_root_mean_squared_error: 1.0630
# Loss = 1.388352394104004, Y1_loss = 0.2584258019924164, Y1_mse = 0.508355975151062, Y2_loss = 1.1299266815185547, Y2_mse = 1.062980055809021

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
